# %%
#import pandas
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
#bring in dataframe
df = pd.read_csv(r"C:\Users\Burgundy\Documents\Data Analysis Projects\Project7-MovieData\MovieAndTVData.csv")
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
#Remove not needed columns
df = df.drop(columns = ["STARS", "ONE-LINE", "VOTES"] )
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  RunTime Gross
# 0         \nAction, Horror, Thriller                 6.1    121.0   NaN
# 1     \nAnimation, Action, Adventure                 5.0     25.0   NaN
# 2          \nDrama, Horror, Thriller                 8.2     44.0   NaN
# ...

# %%
#Remove unnecessary duplicate values
df = df.drop_duplicates()
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9975                             Ultraman     (2019– )
# 9979                    Never Have I Ever     (2020– )
# 9993                            Totenfrau     (2022– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
#
#                                            GENRE  RATING  RunTime Gross
# 0         \nAction, Horror, Thriller                 6.1    121.0   NaN
# 1     \nAnimation, Action, Adventure                 5.0     25.0   NaN
# 2          \nDrama, Horror, Thriller                 8.2     44.0   NaN
# ...

# %%
#Remove end year from TV shows
df["YEAR"] = df["YEAR"].str.split("–").str[0]
df
# Out:
# C:\Users\Burgundy\AppData\Local\Temp\ipykernel_16372\1798950188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["YEAR"] = df["YEAR"].str.split("–").str[0]
#                                    MOVIES    YEAR  \
# 0                           Blood Red Sky  (2021)
# 1     Masters of the Universe: Revelation   (2021
# 2                        The Walking Dead   (2010
# 3                          Rick and Morty   (2013
# 4                         Army of Thieves  (2021)
# ...                                   ...     ...
# 9975                             Ultraman   (2019
# 9979                    Never Have I Ever   (2020
# 9993                            Totenfrau   (2022
# 9995                               Arcane   (2021
# ...

# %%
#Strip text and symbols from year
df["YEAR"] = df["YEAR"].str.strip("()")
df["YEAR"] = df["YEAR"].str.replace(") (", "", n = -1, case = False, regex = False)
df["YEAR"] = df["YEAR"].str.strip("I TV Special Movie Vid TV Short")
df
# Out:
# C:\Users\Burgundy\AppData\Local\Temp\ipykernel_16372\3815707282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["YEAR"] = df["YEAR"].str.strip("()")
#                                    MOVIES  YEAR  \
# 0                           Blood Red Sky  2021
# 1     Masters of the Universe: Revelation  2021
# 2                        The Walking Dead  2010
# 3                          Rick and Morty  2013
# 4                         Army of Thieves  2021
# ...                                   ...   ...
# 9975                             Ultraman  2019
# 9979                    Never Have I Ever  2020
# 9993                            Totenfrau  2022
# 9995                               Arcane  2021
# ...

# %%
df
# Out:
#                                    MOVIES  YEAR  \
# 0                           Blood Red Sky  2021
# 1     Masters of the Universe: Revelation  2021
# 2                        The Walking Dead  2010
# 3                          Rick and Morty  2013
# 4                         Army of Thieves  2021
# ...                                   ...   ...
# 9975                             Ultraman  2019
# 9979                    Never Have I Ever  2020
# 9993                            Totenfrau  2022
# 9995                               Arcane  2021
# 9996                    Heart of Invictus  2022
#
#                                            GENRE  RATING  RunTime Gross
# 0         \nAction, Horror, Thriller                 6.1    121.0   NaN
# 1     \nAnimation, Action, Adventure                 5.0     25.0   NaN
# 2          \nDrama, Horror, Thriller                 8.2     44.0   NaN
# 3     \nAnimation, Adventure, Comedy                 9.2     23.0   NaN
# ...

# %%
#Reformat Gross Column
df["Gross"] = df["Gross"].str.strip("$BM")

#Change Gross column datatype to float
df['Gross'] = df['Gross'].astype('float')
df[df[['Gross']].notna().all(axis=1)]
# Out:
# C:\Users\Burgundy\AppData\Local\Temp\ipykernel_16372\4268625795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gross"] = df["Gross"].str.strip("$BM")
# C:\Users\Burgundy\AppData\Local\Temp\ipykernel_16372\4268625795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gross'] = df['Gross'].astype('float')
#                                                  MOVIES  YEAR  \
# 77                               The Hitman's Bodyguard  2017
# ...

# %%
#Remove unwanted characters from Genre column
df["GENRE"] = df["GENRE"].str.strip("\n")
df
# Out:
# C:\Users\Burgundy\AppData\Local\Temp\ipykernel_16372\2149096397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GENRE"] = df["GENRE"].str.strip("\n")
#                                    MOVIES  YEAR  \
# 0                           Blood Red Sky  2021
# 1     Masters of the Universe: Revelation  2021
# 2                        The Walking Dead  2010
# 3                          Rick and Morty  2013
# 4                         Army of Thieves  2021
# ...                                   ...   ...
# 9975                             Ultraman  2019
# 9979                    Never Have I Ever  2020
# 9993                            Totenfrau  2022
# 9995                               Arcane  2021
# ...

# %%
#Saved cleaned version of data in a new file
df.to_excel("Movie Data Cleaned.xlsx")
